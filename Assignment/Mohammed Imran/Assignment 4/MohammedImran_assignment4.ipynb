# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "collapsed_sections": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "source": [
        "**Importing** **the** **libraries**"
      ],
      "metadata": {
        "id": "wN7qBcvxaC_z"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "import pandas as pd\n",
        "import numpy as np\n",
        "import matplotlib.pyplot as plt\n",
        "import seaborn as sns\n",
        "from sklearn.model_selection import train_test_split\n",
        "from sklearn.preprocessing import LabelEncoder\n",
        "from keras.models import Model,Sequential\n",
        "from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding\n",
        "from keras.optimizers import Adam\n",
        "from keras.preprocessing.text import Tokenizer\n",
        "from keras.preprocessing import sequence\n",
        "from keras.utils import pad_sequences\n",
        "from keras.utils import to_categorical\n",
        "from keras.callbacks import EarlyStopping\n",
        "%matplotlib inline\n"
      ],
      "metadata": {
        "id": "_plGwx1aaMIg"
      },
      "execution_count": 1,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "from google.colab import drive\n",
        "drive.mount('/content/drive')"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "aqKBuclnlMvS",
        "outputId": "a31dbc91-31eb-4bb2-82e7-3d95e24f83f8"
      },
      "execution_count": 2,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Mounted at /content/drive\n"
          ]
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "**Reading** **the** **dataset**"
      ],
      "metadata": {
        "id": "PnMYl7rza2dK"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "df = pd.read_csv('/content/drive/MyDrive/spam.csv',encoding='latin-1')\n",
        "df.head()\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 206
        },
        "id": "iR6LXy-za-FY",
        "outputId": "646d1906-70e3-494e-9f89-7c937119b31d"
      },
      "execution_count": 3,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "     v1                                                 v2 Unnamed: 2  \\\n",
              "0   ham  Go until jurong point, crazy.. Available only ...        NaN   \n",
              "1   ham                      Ok lar... Joking wif u oni...        NaN   \n",
              "2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN   \n",
              "3   ham  U dun say so early hor... U c already then say...        NaN   \n",
              "4   ham  Nah I don't think he goes to usf, he lives aro...        NaN   \n",
              "\n",
              "  Unnamed: 3 Unnamed: 4  \n",
              "0        NaN        NaN  \n",
              "1        NaN        NaN  \n",
              "2        NaN        NaN  \n",
              "3        NaN        NaN  \n",
              "4        NaN        NaN  "
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-7a1673e9-5260-49be-9777-e578a3f7c5c8\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>v1</th>\n",
              "      <th>v2</th>\n",
              "      <th>Unnamed: 2</th>\n",
              "      <th>Unnamed: 3</th>\n",
              "      <th>Unnamed: 4</th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>0</th>\n",
              "      <td>ham</td>\n",
              "      <td>Go until jurong point, crazy.. Available only ...</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>1</th>\n",
              "      <td>ham</td>\n",
              "      <td>Ok lar... Joking wif u oni...</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>2</th>\n",
              "      <td>spam</td>\n",
              "      <td>Free entry in 2 a wkly comp to win FA Cup fina...</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>3</th>\n",
              "      <td>ham</td>\n",
              "      <td>U dun say so early hor... U c already then say...</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>4</th>\n",
              "      <td>ham</td>\n",
              "      <td>Nah I don't think he goes to usf, he lives aro...</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "      <td>NaN</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-7a1673e9-5260-49be-9777-e578a3f7c5c8')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-7a1673e9-5260-49be-9777-e578a3f7c5c8 button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-7a1673e9-5260-49be-9777-e578a3f7c5c8');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 3
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)\n",
        "df.info()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "VdVbdZHcbYgO",
        "outputId": "ba8a386b-c2be-4a87-fc84-3822f4468d27"
      },
      "execution_count": 4,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'pandas.core.frame.DataFrame'>\n",
            "RangeIndex: 5572 entries, 0 to 5571\n",
            "Data columns (total 2 columns):\n",
            " #   Column  Non-Null Count  Dtype \n",
            "---  ------  --------------  ----- \n",
            " 0   v1      5572 non-null   object\n",
            " 1   v2      5572 non-null   object\n",
            "dtypes: object(2)\n",
            "memory usage: 87.2+ KB\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "sns.countplot(df.v1)\n",
        "plt.xlabel('Label')\n",
        "plt.title('Number of ham and spam messages')\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 367
        },
        "id": "1oCcVv_2baSN",
        "outputId": "afbf370b-50f0-4145-dd65-48518decee7a"
      },
      "execution_count": 5,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stderr",
          "text": [
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n"
          ]
        },
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "Text(0.5, 1.0, 'Number of ham and spam messages')"
            ]
          },
          "metadata": {},
          "execution_count": 5
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "X = df.v2\n",
        "Y = df.v1\n",
        "le = LabelEncoder()\n",
        "Y = le.fit_transform(Y)\n",
        "Y = Y.reshape(-1,1)"
      ],
      "metadata": {
        "id": "Df4Z9022bh6-"
      },
      "execution_count": 6,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)\n"
      ],
      "metadata": {
        "id": "Nyesd4EabxuM"
      },
      "execution_count": 7,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "source": [
        "**Process the data**"
      ],
      "metadata": {
        "id": "FRuvmIAbj2Fz"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "max_words = 1000\n",
        "max_len = 150\n",
        "tok = Tokenizer(num_words=max_words)\n",
        "tok.fit_on_texts(X_train)\n",
        "sequences = tok.texts_to_sequences(X_train)\n",
        "sequences_matrix = pad_sequences(sequences,maxlen=max_len)\n",
        "sequences_matrix"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "x8vSHWa9bz1d",
        "outputId": "78dd74a3-0822-4414-c46b-7536eb28ceea"
      },
      "execution_count": 8,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "array([[  0,   0,   0, ..., 841,  17, 428],\n",
              "       [  0,   0,   0, ..., 370,  12,  14],\n",
              "       [  0,   0,   0, ...,  39,  38,  32],\n",
              "       ...,\n",
              "       [  0,   0,   0, ...,  13, 608, 180],\n",
              "       [  0,   0,   0, ...,  20,   6, 204],\n",
              "       [  0,   0,   0, ...,  18,   5, 144]], dtype=int32)"
            ]
          },
          "metadata": {},
          "execution_count": 8
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "tok.index_word"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "9ldXOnM_c3eQ",
        "outputId": "95b33932-90bc-43f0-b6f1-805e6049080a"
      },
      "execution_count": 9,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "{1: 'i',\n",
              " 2: 'to',\n",
              " 3: 'you',\n",
              " 4: 'a',\n",
              " 5: 'the',\n",
              " 6: 'u',\n",
              " 7: 'and',\n",
              " 8: 'in',\n",
              " 9: 'is',\n",
              " 10: 'me',\n",
              " 11: 'my',\n",
              " 12: 'for',\n",
              " 13: 'your',\n",
              " 14: 'it',\n",
              " 15: 'of',\n",
              " 16: 'call',\n",
              " 17: 'have',\n",
              " 18: 'on',\n",
              " 19: 'that',\n",
              " 20: '2',\n",
              " 21: 'are',\n",
              " 22: 'now',\n",
              " 23: 'so',\n",
              " 24: 'not',\n",
              " 25: 'but',\n",
              " 26: 'or',\n",
              " 27: 'at',\n",
              " 28: 'can',\n",
              " 29: 'do',\n",
              " 30: 'with',\n",
              " 31: 'be',\n",
              " 32: 'get',\n",
              " 33: 'if',\n",
              " 34: 'just',\n",
              " 35: \"i'm\",\n",
              " 36: 'no',\n",
              " 37: 'ur',\n",
              " 38: 'will',\n",
              " 39: 'we',\n",
              " 40: 'gt',\n",
              " 41: 'lt',\n",
              " 42: 'this',\n",
              " 43: '4',\n",
              " 44: 'up',\n",
              " 45: 'when',\n",
              " 46: 'from',\n",
              " 47: 'how',\n",
              " 48: 'ok',\n",
              " 49: 'free',\n",
              " 50: 'go',\n",
              " 51: 'out',\n",
              " 52: 'all',\n",
              " 53: 'what',\n",
              " 54: 'know',\n",
              " 55: 'like',\n",
              " 56: 'was',\n",
              " 57: 'got',\n",
              " 58: 'good',\n",
              " 59: 'then',\n",
              " 60: 'come',\n",
              " 61: 'its',\n",
              " 62: 'only',\n",
              " 63: 'am',\n",
              " 64: 'time',\n",
              " 65: 'day',\n",
              " 66: 'love',\n",
              " 67: 'there',\n",
              " 68: 'send',\n",
              " 69: 'he',\n",
              " 70: 'as',\n",
              " 71: 'text',\n",
              " 72: 'want',\n",
              " 73: 'one',\n",
              " 74: 'txt',\n",
              " 75: 'home',\n",
              " 76: 'going',\n",
              " 77: \"i'll\",\n",
              " 78: 'about',\n",
              " 79: 'by',\n",
              " 80: 'lor',\n",
              " 81: 'need',\n",
              " 82: 'r',\n",
              " 83: 'see',\n",
              " 84: 'still',\n",
              " 85: 'stop',\n",
              " 86: 'da',\n",
              " 87: 'today',\n",
              " 88: 'dont',\n",
              " 89: 'sorry',\n",
              " 90: 'back',\n",
              " 91: 'k',\n",
              " 92: 'reply',\n",
              " 93: 'our',\n",
              " 94: 'n',\n",
              " 95: 'she',\n",
              " 96: 'tell',\n",
              " 97: 'mobile',\n",
              " 98: 'her',\n",
              " 99: 'hi',\n",
              " 100: 'later',\n",
              " 101: \"don't\",\n",
              " 102: 'take',\n",
              " 103: 'please',\n",
              " 104: 'any',\n",
              " 105: 'pls',\n",
              " 106: 'new',\n",
              " 107: 'they',\n",
              " 108: 'think',\n",
              " 109: 'been',\n",
              " 110: 'some',\n",
              " 111: 'great',\n",
              " 112: 'did',\n",
              " 113: 'phone',\n",
              " 114: 'here',\n",
              " 115: 'has',\n",
              " 116: 'well',\n",
              " 117: 'ì',\n",
              " 118: 'where',\n",
              " 119: 'dear',\n",
              " 120: 'much',\n",
              " 121: 'd',\n",
              " 122: 'hey',\n",
              " 123: 'claim',\n",
              " 124: '1',\n",
              " 125: 'hope',\n",
              " 126: 'an',\n",
              " 127: 'msg',\n",
              " 128: 'night',\n",
              " 129: 'who',\n",
              " 130: 'too',\n",
              " 131: 'more',\n",
              " 132: 'him',\n",
              " 133: 'make',\n",
              " 134: 'week',\n",
              " 135: 'number',\n",
              " 136: 'had',\n",
              " 137: 'should',\n",
              " 138: 'give',\n",
              " 139: 'work',\n",
              " 140: 'www',\n",
              " 141: 'happy',\n",
              " 142: 'yes',\n",
              " 143: 'oh',\n",
              " 144: 'way',\n",
              " 145: 'e',\n",
              " 146: 'wat',\n",
              " 147: 'say',\n",
              " 148: 'c',\n",
              " 149: 'prize',\n",
              " 150: 'ask',\n",
              " 151: 'im',\n",
              " 152: 'message',\n",
              " 153: 'meet',\n",
              " 154: 'right',\n",
              " 155: 'amp',\n",
              " 156: 'after',\n",
              " 157: \"it's\",\n",
              " 158: 'already',\n",
              " 159: 'yeah',\n",
              " 160: 'tomorrow',\n",
              " 161: 'doing',\n",
              " 162: 'said',\n",
              " 163: 'why',\n",
              " 164: 'cash',\n",
              " 165: '3',\n",
              " 166: 'last',\n",
              " 167: 'morning',\n",
              " 168: 'find',\n",
              " 169: 'them',\n",
              " 170: 'babe',\n",
              " 171: 'life',\n",
              " 172: 'really',\n",
              " 173: 'miss',\n",
              " 174: 'win',\n",
              " 175: 'would',\n",
              " 176: 'lol',\n",
              " 177: 'sure',\n",
              " 178: 'b',\n",
              " 179: 'let',\n",
              " 180: 'com',\n",
              " 181: 'very',\n",
              " 182: 'also',\n",
              " 183: 'urgent',\n",
              " 184: 'thanks',\n",
              " 185: 'cos',\n",
              " 186: 'nokia',\n",
              " 187: 'every',\n",
              " 188: 't',\n",
              " 189: 'buy',\n",
              " 190: 'keep',\n",
              " 191: 'over',\n",
              " 192: 's',\n",
              " 193: 'again',\n",
              " 194: 'anything',\n",
              " 195: 'something',\n",
              " 196: 'uk',\n",
              " 197: 'won',\n",
              " 198: 'first',\n",
              " 199: 'us',\n",
              " 200: 'were',\n",
              " 201: 'min',\n",
              " 202: '150p',\n",
              " 203: 'contact',\n",
              " 204: 'care',\n",
              " 205: 'his',\n",
              " 206: 'sent',\n",
              " 207: 'thing',\n",
              " 208: \"i've\",\n",
              " 209: 'soon',\n",
              " 210: '5',\n",
              " 211: 'which',\n",
              " 212: 'wait',\n",
              " 213: 'pick',\n",
              " 214: 'nice',\n",
              " 215: 'went',\n",
              " 216: 'always',\n",
              " 217: 'chat',\n",
              " 218: 'before',\n",
              " 219: 'money',\n",
              " 220: 'cant',\n",
              " 221: 'someone',\n",
              " 222: 'could',\n",
              " 223: 'per',\n",
              " 224: 'feel',\n",
              " 225: 'ya',\n",
              " 226: 'many',\n",
              " 227: 'around',\n",
              " 228: '50',\n",
              " 229: 'tone',\n",
              " 230: 'wish',\n",
              " 231: 'sleep',\n",
              " 232: 'next',\n",
              " 233: 'place',\n",
              " 234: 'sms',\n",
              " 235: 'gud',\n",
              " 236: 'tonight',\n",
              " 237: 'even',\n",
              " 238: 'v',\n",
              " 239: 'ìï',\n",
              " 240: 'co',\n",
              " 241: 'wan',\n",
              " 242: 'friends',\n",
              " 243: 'off',\n",
              " 244: 'customer',\n",
              " 245: 'things',\n",
              " 246: 'x',\n",
              " 247: 'gonna',\n",
              " 248: 'other',\n",
              " 249: 'service',\n",
              " 250: 'may',\n",
              " 251: 'late',\n",
              " 252: 'hello',\n",
              " 253: 'leave',\n",
              " 254: 'thought',\n",
              " 255: 'waiting',\n",
              " 256: 'thk',\n",
              " 257: 'dun',\n",
              " 258: 'guaranteed',\n",
              " 259: 'down',\n",
              " 260: \"that's\",\n",
              " 261: 'try',\n",
              " 262: 'told',\n",
              " 263: 'lunch',\n",
              " 264: 'fine',\n",
              " 265: 'live',\n",
              " 266: 'year',\n",
              " 267: \"can't\",\n",
              " 268: 'name',\n",
              " 269: 'heart',\n",
              " 270: 'coming',\n",
              " 271: 'mins',\n",
              " 272: '18',\n",
              " 273: 'special',\n",
              " 274: 'getting',\n",
              " 275: 'people',\n",
              " 276: 'same',\n",
              " 277: 'help',\n",
              " 278: 'haha',\n",
              " 279: 'holiday',\n",
              " 280: 'done',\n",
              " 281: 'man',\n",
              " 282: 'friend',\n",
              " 283: 'draw',\n",
              " 284: 'use',\n",
              " 285: 'yet',\n",
              " 286: '16',\n",
              " 287: \"you're\",\n",
              " 288: 'trying',\n",
              " 289: 'ill',\n",
              " 290: 'stuff',\n",
              " 291: '6',\n",
              " 292: 'best',\n",
              " 293: 'job',\n",
              " 294: 'line',\n",
              " 295: 'y',\n",
              " 296: 'house',\n",
              " 297: \"didn't\",\n",
              " 298: 'talk',\n",
              " 299: 'yup',\n",
              " 300: 'end',\n",
              " 301: 'ready',\n",
              " 302: 'bit',\n",
              " 303: 'few',\n",
              " 304: 'being',\n",
              " 305: 'dat',\n",
              " 306: 'play',\n",
              " 307: 'days',\n",
              " 308: 'having',\n",
              " 309: 'finish',\n",
              " 310: 'class',\n",
              " 311: 'god',\n",
              " 312: 'smile',\n",
              " 313: 'another',\n",
              " 314: 'person',\n",
              " 315: 'receive',\n",
              " 316: 'cs',\n",
              " 317: 'latest',\n",
              " 318: 'account',\n",
              " 319: 'long',\n",
              " 320: 'thats',\n",
              " 321: 'mind',\n",
              " 322: 'month',\n",
              " 323: 'problem',\n",
              " 324: '7',\n",
              " 325: 'eat',\n",
              " 326: 'awarded',\n",
              " 327: 'jus',\n",
              " 328: 'check',\n",
              " 329: 'chance',\n",
              " 330: 'shows',\n",
              " 331: 'å£1',\n",
              " 332: 'birthday',\n",
              " 333: 'lar',\n",
              " 334: 'liao',\n",
              " 335: 'never',\n",
              " 336: 'lot',\n",
              " 337: '1st',\n",
              " 338: 'cool',\n",
              " 339: 'guys',\n",
              " 340: 'meeting',\n",
              " 341: 'early',\n",
              " 342: 'better',\n",
              " 343: 'sir',\n",
              " 344: 'yo',\n",
              " 345: 'car',\n",
              " 346: 'shit',\n",
              " 347: 'because',\n",
              " 348: 'nothing',\n",
              " 349: 'wk',\n",
              " 350: 'two',\n",
              " 351: 'might',\n",
              " 352: 'big',\n",
              " 353: 'cost',\n",
              " 354: 'called',\n",
              " 355: 'wanna',\n",
              " 356: 'aight',\n",
              " 357: 'wont',\n",
              " 358: 'word',\n",
              " 359: 'dunno',\n",
              " 360: 'luv',\n",
              " 361: 'tv',\n",
              " 362: 'bt',\n",
              " 363: 'enjoy',\n",
              " 364: 'world',\n",
              " 365: 'camera',\n",
              " 366: 'pa',\n",
              " 367: 'video',\n",
              " 368: 'ever',\n",
              " 369: 'into',\n",
              " 370: 'apply',\n",
              " 371: 'guess',\n",
              " 372: 'than',\n",
              " 373: 'room',\n",
              " 374: 'pay',\n",
              " 375: 'maybe',\n",
              " 376: 'probably',\n",
              " 377: '150ppm',\n",
              " 378: 'reach',\n",
              " 379: 'sweet',\n",
              " 380: 'look',\n",
              " 381: 'ah',\n",
              " 382: 'start',\n",
              " 383: 'å£1000',\n",
              " 384: 'dis',\n",
              " 385: 'dinner',\n",
              " 386: 'princess',\n",
              " 387: 'girl',\n",
              " 388: 'easy',\n",
              " 389: '10',\n",
              " 390: 'once',\n",
              " 391: 'half',\n",
              " 392: 'does',\n",
              " 393: 'forgot',\n",
              " 394: 'speak',\n",
              " 395: 'rate',\n",
              " 396: 'll',\n",
              " 397: 'office',\n",
              " 398: 'plan',\n",
              " 399: 'orange',\n",
              " 400: 'bad',\n",
              " 401: \"he's\",\n",
              " 402: 'xxx',\n",
              " 403: 'watch',\n",
              " 404: 'box',\n",
              " 405: 'minutes',\n",
              " 406: 'real',\n",
              " 407: 'landline',\n",
              " 408: 'evening',\n",
              " 409: '9',\n",
              " 410: \"how's\",\n",
              " 411: 'part',\n",
              " 412: 'actually',\n",
              " 413: 'bed',\n",
              " 414: 'those',\n",
              " 415: 'offer',\n",
              " 416: 'without',\n",
              " 417: 'wife',\n",
              " 418: '8',\n",
              " 419: 'entry',\n",
              " 420: 'hear',\n",
              " 421: 'though',\n",
              " 422: 'between',\n",
              " 423: 'quite',\n",
              " 424: 'sat',\n",
              " 425: 'hour',\n",
              " 426: 'watching',\n",
              " 427: 'fuck',\n",
              " 428: 'fun',\n",
              " 429: 'everything',\n",
              " 430: 'working',\n",
              " 431: 'leh',\n",
              " 432: 'dad',\n",
              " 433: 'bring',\n",
              " 434: 'looking',\n",
              " 435: 'weekend',\n",
              " 436: 'put',\n",
              " 437: 'kiss',\n",
              " 438: 'baby',\n",
              " 439: 'code',\n",
              " 440: 'details',\n",
              " 441: 'abt',\n",
              " 442: 'hav',\n",
              " 443: 'must',\n",
              " 444: 'ringtone',\n",
              " 445: 'pain',\n",
              " 446: 'afternoon',\n",
              " 447: 'school',\n",
              " 448: 'decimal',\n",
              " 449: 'thanx',\n",
              " 450: 'made',\n",
              " 451: 'anyway',\n",
              " 452: 'network',\n",
              " 453: 'shopping',\n",
              " 454: 'boy',\n",
              " 455: 'po',\n",
              " 456: 'den',\n",
              " 457: 'wif',\n",
              " 458: 'selected',\n",
              " 459: 'collect',\n",
              " 460: 'bus',\n",
              " 461: 'missing',\n",
              " 462: '000',\n",
              " 463: 'town',\n",
              " 464: 'until',\n",
              " 465: 'm',\n",
              " 466: 'thank',\n",
              " 467: 'while',\n",
              " 468: 'worry',\n",
              " 469: 'wot',\n",
              " 470: \"there's\",\n",
              " 471: 'award',\n",
              " 472: 'mail',\n",
              " 473: 'remember',\n",
              " 474: 'wake',\n",
              " 475: 'makes',\n",
              " 476: 'shall',\n",
              " 477: 'little',\n",
              " 478: 'since',\n",
              " 479: 'enough',\n",
              " 480: 'okay',\n",
              " 481: 'came',\n",
              " 482: 'plz',\n",
              " 483: 'asked',\n",
              " 484: 're',\n",
              " 485: 'plus',\n",
              " 486: 'says',\n",
              " 487: 'xmas',\n",
              " 488: 'gift',\n",
              " 489: 'weekly',\n",
              " 490: 'lei',\n",
              " 491: 'tmr',\n",
              " 492: 'hair',\n",
              " 493: 'years',\n",
              " 494: 'most',\n",
              " 495: 'true',\n",
              " 496: 'show',\n",
              " 497: 'able',\n",
              " 498: 'wanted',\n",
              " 499: 'valid',\n",
              " 500: 'didnt',\n",
              " 501: 'calls',\n",
              " 502: 'g',\n",
              " 503: 'update',\n",
              " 504: 'join',\n",
              " 505: 'price',\n",
              " 506: 'collection',\n",
              " 507: 'dude',\n",
              " 508: 'bored',\n",
              " 509: '2nd',\n",
              " 510: 'test',\n",
              " 511: 'means',\n",
              " 512: 'guy',\n",
              " 513: 'till',\n",
              " 514: 'important',\n",
              " 515: 'address',\n",
              " 516: 'tones',\n",
              " 517: 'ard',\n",
              " 518: 'away',\n",
              " 519: 'times',\n",
              " 520: 'sexy',\n",
              " 521: 'trip',\n",
              " 522: 'double',\n",
              " 523: 'alright',\n",
              " 524: '10p',\n",
              " 525: 'feeling',\n",
              " 526: 'else',\n",
              " 527: 'online',\n",
              " 528: 'id',\n",
              " 529: 'juz',\n",
              " 530: 'either',\n",
              " 531: 'together',\n",
              " 532: 'de',\n",
              " 533: 'left',\n",
              " 534: 'sch',\n",
              " 535: 'haf',\n",
              " 536: 'run',\n",
              " 537: \"what's\",\n",
              " 538: 'lose',\n",
              " 539: 'mob',\n",
              " 540: 'messages',\n",
              " 541: 'todays',\n",
              " 542: 'net',\n",
              " 543: 'colour',\n",
              " 544: 'goes',\n",
              " 545: 'hurt',\n",
              " 546: 'texts',\n",
              " 547: '500',\n",
              " 548: 'havent',\n",
              " 549: 'national',\n",
              " 550: 'saw',\n",
              " 551: 'order',\n",
              " 552: 'book',\n",
              " 553: 'å£100',\n",
              " 554: 'story',\n",
              " 555: 'post',\n",
              " 556: 'å£500',\n",
              " 557: 'music',\n",
              " 558: 'making',\n",
              " 559: '8007',\n",
              " 560: 'old',\n",
              " 561: 'shop',\n",
              " 562: 'yesterday',\n",
              " 563: 'stay',\n",
              " 564: 'these',\n",
              " 565: 'å£2000',\n",
              " 566: 'friendship',\n",
              " 567: 'driving',\n",
              " 568: 'goin',\n",
              " 569: \"we're\",\n",
              " 570: 'tot',\n",
              " 571: 'date',\n",
              " 572: 'nite',\n",
              " 573: 'both',\n",
              " 574: 'yourself',\n",
              " 575: 'oso',\n",
              " 576: 'tried',\n",
              " 577: 'face',\n",
              " 578: 'attempt',\n",
              " 579: 'okie',\n",
              " 580: 'coz',\n",
              " 581: 'sleeping',\n",
              " 582: 'took',\n",
              " 583: 'points',\n",
              " 584: 'happen',\n",
              " 585: 'neva',\n",
              " 586: 'aft',\n",
              " 587: 'change',\n",
              " 588: 'yours',\n",
              " 589: 'games',\n",
              " 590: 'gr8',\n",
              " 591: 'food',\n",
              " 592: \"won't\",\n",
              " 593: 'finished',\n",
              " 594: 'answer',\n",
              " 595: 'mean',\n",
              " 596: 'sae',\n",
              " 597: 'å£5000',\n",
              " 598: 'words',\n",
              " 599: 'bonus',\n",
              " 600: 'drive',\n",
              " 601: 'land',\n",
              " 602: 'pub',\n",
              " 603: 'wants',\n",
              " 604: 'everyone',\n",
              " 605: 'found',\n",
              " 606: 'vouchers',\n",
              " 607: 'sad',\n",
              " 608: 'http',\n",
              " 609: 'drink',\n",
              " 610: 'top',\n",
              " 611: 'wen',\n",
              " 612: 'email',\n",
              " 613: \"we'll\",\n",
              " 614: 'huh',\n",
              " 615: 'saying',\n",
              " 616: 'busy',\n",
              " 617: 'available',\n",
              " 618: 'ring',\n",
              " 619: '12hrs',\n",
              " 620: 'drop',\n",
              " 621: 'brother',\n",
              " 622: 'club',\n",
              " 623: 'missed',\n",
              " 624: 'set',\n",
              " 625: 'pm',\n",
              " 626: 'taking',\n",
              " 627: 'family',\n",
              " 628: 'comes',\n",
              " 629: 'til',\n",
              " 630: 'chikku',\n",
              " 631: 'await',\n",
              " 632: 'search',\n",
              " 633: 'charge',\n",
              " 634: 'rite',\n",
              " 635: '11',\n",
              " 636: 'full',\n",
              " 637: 'game',\n",
              " 638: 'started',\n",
              " 639: 'simple',\n",
              " 640: 'noe',\n",
              " 641: 'head',\n",
              " 642: 'gd',\n",
              " 643: 'sis',\n",
              " 644: 'alone',\n",
              " 645: 'dreams',\n",
              " 646: 'tho',\n",
              " 647: 'beautiful',\n",
              " 648: 'wid',\n",
              " 649: 'thinking',\n",
              " 650: 'hot',\n",
              " 651: 'movie',\n",
              " 652: \"c's\",\n",
              " 653: '86688',\n",
              " 654: 'calling',\n",
              " 655: 'final',\n",
              " 656: 'lets',\n",
              " 657: 'private',\n",
              " 658: 'awesome',\n",
              " 659: 'mine',\n",
              " 660: 'delivery',\n",
              " 661: \"she's\",\n",
              " 662: 'pounds',\n",
              " 663: 'news',\n",
              " 664: 'break',\n",
              " 665: '750',\n",
              " 666: 'rs',\n",
              " 667: 'frnd',\n",
              " 668: 'card',\n",
              " 669: 'leaving',\n",
              " 670: 'carlos',\n",
              " 671: 'congrats',\n",
              " 672: 'touch',\n",
              " 673: 'poly',\n",
              " 674: 'prob',\n",
              " 675: 'oredi',\n",
              " 676: 'hard',\n",
              " 677: 'ltd',\n",
              " 678: 'cause',\n",
              " 679: 'boytoy',\n",
              " 680: 'smiling',\n",
              " 681: 'needs',\n",
              " 682: 'question',\n",
              " 683: 'nt',\n",
              " 684: 'sister',\n",
              " 685: 'second',\n",
              " 686: 'close',\n",
              " 687: 'row',\n",
              " 688: 'wrong',\n",
              " 689: 'pics',\n",
              " 690: 'loving',\n",
              " 691: 'pic',\n",
              " 692: 'expires',\n",
              " 693: 'minute',\n",
              " 694: \"''\",\n",
              " 695: 'services',\n",
              " 696: 'eve',\n",
              " 697: 'whats',\n",
              " 698: 'believe',\n",
              " 699: 'mum',\n",
              " 700: \"haven't\",\n",
              " 701: 'fast',\n",
              " 702: 'kind',\n",
              " 703: 'tomo',\n",
              " 704: 'forget',\n",
              " 705: 'ten',\n",
              " 706: 'anyone',\n",
              " 707: 'happened',\n",
              " 708: 'voucher',\n",
              " 709: 'w',\n",
              " 710: 'knw',\n",
              " 711: 'frnds',\n",
              " 712: 'read',\n",
              " 713: 'fri',\n",
              " 714: '08000839402',\n",
              " 715: 'statement',\n",
              " 716: 'saturday',\n",
              " 717: 'nope',\n",
              " 718: 'fancy',\n",
              " 719: 'party',\n",
              " 720: 'mobileupd8',\n",
              " 721: 'visit',\n",
              " 722: 'sunday',\n",
              " 723: 'identifier',\n",
              " 724: 'player',\n",
              " 725: 'decided',\n",
              " 726: 'parents',\n",
              " 727: 'hours',\n",
              " 728: 'operator',\n",
              " 729: 'blue',\n",
              " 730: 'sounds',\n",
              " 731: 'chennai',\n",
              " 732: 'dating',\n",
              " 733: 'almost',\n",
              " 734: 'bslvyl',\n",
              " 735: 'hmmm',\n",
              " 736: 'case',\n",
              " 737: 'understand',\n",
              " 738: 'darlin',\n",
              " 739: 'age',\n",
              " 740: 'ni8',\n",
              " 741: 'don',\n",
              " 742: 'mates',\n",
              " 743: 'lucky',\n",
              " 744: 'walk',\n",
              " 745: 'winner',\n",
              " 746: 'each',\n",
              " 747: 'lovely',\n",
              " 748: '\\x89û',\n",
              " 749: 'weeks',\n",
              " 750: 'info',\n",
              " 751: 'choose',\n",
              " 752: '30',\n",
              " 753: 'å£250',\n",
              " 754: 'tel',\n",
              " 755: 'msgs',\n",
              " 756: 'sun',\n",
              " 757: 'hungry',\n",
              " 758: 'lesson',\n",
              " 759: 'wil',\n",
              " 760: 'auction',\n",
              " 761: 'takes',\n",
              " 762: 'pretty',\n",
              " 763: 'course',\n",
              " 764: 'finally',\n",
              " 765: 'tc',\n",
              " 766: 'congratulations',\n",
              " 767: '100',\n",
              " 768: 'motorola',\n",
              " 769: 'worth',\n",
              " 770: 'happiness',\n",
              " 771: \"you've\",\n",
              " 772: 'content',\n",
              " 773: '08000930705',\n",
              " 774: 'meant',\n",
              " 775: 'company',\n",
              " 776: 'type',\n",
              " 777: 'yar',\n",
              " 778: 'used',\n",
              " 779: 'talking',\n",
              " 780: 'quiz',\n",
              " 781: 'mu',\n",
              " 782: 'whatever',\n",
              " 783: 'numbers',\n",
              " 784: 'gal',\n",
              " 785: 'smth',\n",
              " 786: 'mate',\n",
              " 787: 'o',\n",
              " 788: 'angry',\n",
              " 789: 'eh',\n",
              " 790: 'hit',\n",
              " 791: 'support',\n",
              " 792: 'college',\n",
              " 793: 'die',\n",
              " 794: 'th',\n",
              " 795: 'their',\n",
              " 796: \"you'll\",\n",
              " 797: 'reading',\n",
              " 798: 'seeing',\n",
              " 799: 'opt',\n",
              " 800: 'suite342',\n",
              " 801: '2lands',\n",
              " 802: 'supposed',\n",
              " 803: 'point',\n",
              " 804: 'goodmorning',\n",
              " 805: 'outside',\n",
              " 806: 'unlimited',\n",
              " 807: 'march',\n",
              " 808: 'hand',\n",
              " 809: 'wit',\n",
              " 810: 'yr',\n",
              " 811: 'area',\n",
              " 812: 'john',\n",
              " 813: 'cum',\n",
              " 814: 'secret',\n",
              " 815: 'wkly',\n",
              " 816: 'txts',\n",
              " 817: 'freemsg',\n",
              " 818: 'treat',\n",
              " 819: '800',\n",
              " 820: 'enter',\n",
              " 821: 'whole',\n",
              " 822: 'knew',\n",
              " 823: 'light',\n",
              " 824: 'wonderful',\n",
              " 825: 'stupid',\n",
              " 826: 'open',\n",
              " 827: 'project',\n",
              " 828: \"'\",\n",
              " 829: 'heard',\n",
              " 830: 'lots',\n",
              " 831: 'far',\n",
              " 832: 'sea',\n",
              " 833: 'cut',\n",
              " 834: 'anytime',\n",
              " 835: 'camcorder',\n",
              " 836: 'telling',\n",
              " 837: 'bank',\n",
              " 838: 'friday',\n",
              " 839: 'gone',\n",
              " 840: 'smoke',\n",
              " 841: 'mom',\n",
              " 842: 'mr',\n",
              " 843: 'bout',\n",
              " 844: 'bcoz',\n",
              " 845: 'police',\n",
              " 846: 'picking',\n",
              " 847: 'reason',\n",
              " 848: 'wine',\n",
              " 849: '87066',\n",
              " 850: 'na',\n",
              " 851: 'earlier',\n",
              " 852: 'fr',\n",
              " 853: 'snow',\n",
              " 854: 'hmm',\n",
              " 855: 'mayb',\n",
              " 856: 'xx',\n",
              " 857: 'india',\n",
              " 858: 'log',\n",
              " 859: 'exam',\n",
              " 860: 'via',\n",
              " 861: 'st',\n",
              " 862: 'pobox',\n",
              " 863: '0800',\n",
              " 864: 'unsubscribe',\n",
              " 865: 'hows',\n",
              " 866: 'girls',\n",
              " 867: 'valued',\n",
              " 868: 'computer',\n",
              " 869: 'sex',\n",
              " 870: 'slowly',\n",
              " 871: 'loads',\n",
              " 872: 'somebody',\n",
              " 873: '03',\n",
              " 874: 'credit',\n",
              " 875: 'lost',\n",
              " 876: 'luck',\n",
              " 877: 'couple',\n",
              " 878: 'gas',\n",
              " 879: 'orchard',\n",
              " 880: 'song',\n",
              " 881: 'hold',\n",
              " 882: 'slow',\n",
              " 883: 'phones',\n",
              " 884: 'extra',\n",
              " 885: 'wow',\n",
              " 886: 'rply',\n",
              " 887: 'etc',\n",
              " 888: '2003',\n",
              " 889: 'un',\n",
              " 890: 'redeemed',\n",
              " 891: '04',\n",
              " 892: 'fucking',\n",
              " 893: 'ipod',\n",
              " 894: 'laptop',\n",
              " 895: 'savamob',\n",
              " 896: 'å£3',\n",
              " 897: 'red',\n",
              " 898: 'felt',\n",
              " 899: 'press',\n",
              " 900: 'listen',\n",
              " 901: 'sending',\n",
              " 902: 'questions',\n",
              " 903: 'fone',\n",
              " 904: \"doesn't\",\n",
              " 905: 'clean',\n",
              " 906: 'comp',\n",
              " 907: 'std',\n",
              " 908: 'å£2',\n",
              " 909: 'father',\n",
              " 910: 'gets',\n",
              " 911: 'side',\n",
              " 912: 'safe',\n",
              " 913: 'least',\n",
              " 914: 'mrng',\n",
              " 915: 'difficult',\n",
              " 916: 'caller',\n",
              " 917: 'park',\n",
              " 918: 'christmas',\n",
              " 919: 'ha',\n",
              " 920: '20',\n",
              " 921: 'seen',\n",
              " 922: 'thinks',\n",
              " 923: 'terms',\n",
              " 924: 'immediately',\n",
              " 925: 'ac',\n",
              " 926: 'semester',\n",
              " 927: 'hee',\n",
              " 928: 'small',\n",
              " 929: 'voice',\n",
              " 930: 'dnt',\n",
              " 931: 'somewhere',\n",
              " 932: 'crazy',\n",
              " 933: 'checking',\n",
              " 934: 'kate',\n",
              " 935: 'loved',\n",
              " 936: 'rest',\n",
              " 937: 'abiola',\n",
              " 938: 'å£350',\n",
              " 939: 'darren',\n",
              " 940: 'download',\n",
              " 941: 'move',\n",
              " 942: 'own',\n",
              " 943: 'uncle',\n",
              " 944: 'welcome',\n",
              " 945: 'otherwise',\n",
              " 946: 'truth',\n",
              " 947: 'gn',\n",
              " 948: 'mobiles',\n",
              " 949: 'empty',\n",
              " 950: 'sort',\n",
              " 951: 'ago',\n",
              " 952: 'rental',\n",
              " 953: 'call2optout',\n",
              " 954: 'complimentary',\n",
              " 955: 'different',\n",
              " 956: 'ans',\n",
              " 957: 'offers',\n",
              " 958: 'ass',\n",
              " 959: 'correct',\n",
              " 960: 'entered',\n",
              " 961: 'invited',\n",
              " 962: 'remove',\n",
              " 963: 'frm',\n",
              " 964: 'hmv',\n",
              " 965: 'balance',\n",
              " 966: 'surprise',\n",
              " 967: 'crave',\n",
              " 968: 'drugs',\n",
              " 969: 'met',\n",
              " 970: 'ringtones',\n",
              " 971: 'ex',\n",
              " 972: 'sound',\n",
              " 973: 'usual',\n",
              " 974: 'comin',\n",
              " 975: 'ends',\n",
              " 976: 'jay',\n",
              " 977: \"wasn't\",\n",
              " 978: 'merry',\n",
              " 979: 'direct',\n",
              " 980: 'asap',\n",
              " 981: 'woke',\n",
              " 982: 'noon',\n",
              " 983: 'shower',\n",
              " 984: 'within',\n",
              " 985: 'buying',\n",
              " 986: 'disturb',\n",
              " 987: 'f',\n",
              " 988: 'cd',\n",
              " 989: 'bathe',\n",
              " 990: 'brings',\n",
              " 991: 'study',\n",
              " 992: 'sub',\n",
              " 993: 'information',\n",
              " 994: 'hiya',\n",
              " 995: 'gave',\n",
              " 996: 'ugh',\n",
              " 997: 'hoping',\n",
              " 998: 'ntt',\n",
              " 999: 'txting',\n",
              " 1000: 'getzed',\n",
              " ...}"
            ]
          },
          "metadata": {},
          "execution_count": 9
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "**Creating model and Adding the layers**"
      ],
      "metadata": {
        "id": "7q7hlyuTjKFV"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "TOT_SIZE = len(tok.word_index)+1\n",
        "lstm_model = Sequential()\n",
        "lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))\n",
        "lstm_model.add(LSTM(100))\n",
        "lstm_model.add(Dropout(0.4))\n",
        "lstm_model.add(Dense(20, activation=\"relu\"))\n",
        "lstm_model.add(Dropout(0.3))\n",
        "lstm_model.add(Dense(1, activation = \"sigmoid\"))"
      ],
      "metadata": {
        "id": "j3RtA4Ihe_9G"
      },
      "execution_count": 10,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "source": [
        "**Compile the model**"
      ],
      "metadata": {
        "id": "pK177WZ7jB1d"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "lstm_model.compile(loss = \"binary_crossentropy\", optimizer = \"adam\", metrics = [\"accuracy\"])\n",
        "lstm_model.summary()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "gItoFBABi9QG",
        "outputId": "a0ee015a-981d-489f-89e2-c866511848bf"
      },
      "execution_count": 12,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Model: \"sequential\"\n",
            "_________________________________________________________________\n",
            " Layer (type)                Output Shape              Param #   \n",
            "=================================================================\n",
            " embedding (Embedding)       (None, 150, 32)           263648    \n",
            "                                                                 \n",
            " lstm (LSTM)                 (None, 100)               53200     \n",
            "                                                                 \n",
            " dropout (Dropout)           (None, 100)               0         \n",
            "                                                                 \n",
            " dense (Dense)               (None, 20)                2020      \n",
            "                                                                 \n",
            " dropout_1 (Dropout)         (None, 20)                0         \n",
            "                                                                 \n",
            " dense_1 (Dense)             (None, 1)                 21        \n",
            "                                                                 \n",
            "=================================================================\n",
            "Total params: 318,889\n",
            "Trainable params: 318,889\n",
            "Non-trainable params: 0\n",
            "_________________________________________________________________\n"
          ]
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "**Fit the model**"
      ],
      "metadata": {
        "id": "8qR_Ov4cib1w"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,\n",
        "          validation_split=0.2,\n",
        "          workers=10,\n",
        "           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "I_gluT2Qfjer",
        "outputId": "8f6aa128-2b4c-40d7-c9ca-30c0e5557c42"
      },
      "execution_count": 13,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Epoch 1/10\n",
            "30/30 [==============================] - 14s 379ms/step - loss: 0.4631 - accuracy: 0.8524 - val_loss: 0.3151 - val_accuracy: 0.8650\n",
            "Epoch 2/10\n",
            "30/30 [==============================] - 11s 359ms/step - loss: 0.2174 - accuracy: 0.9311 - val_loss: 0.1200 - val_accuracy: 0.9705\n"
          ]
        },
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "<keras.callbacks.History at 0x7f91f1c140d0>"
            ]
          },
          "metadata": {},
          "execution_count": 13
        }
      ]
    },
    {
      "cell_type": "markdown",
      "source": [
        "**Save the model**"
      ],
      "metadata": {
        "id": "t_Rr6SLciOvg"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "lstm_model.save('sms.h5')"
      ],
      "metadata": {
        "id": "uDoxxzfuh8Z4"
      },
      "execution_count": 14,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "source": [
        "**Test the model**"
      ],
      "metadata": {
        "id": "zva5H2EhlAdZ"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "test_sequences = tok.texts_to_sequences(X_test)\n",
        "test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)"
      ],
      "metadata": {
        "id": "V2QFA689hTL7"
      },
      "execution_count": 15,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "acc = lstm_model.evaluate(test_sequences_matrix,Y_test)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "QnWrbEWvhhKy",
        "outputId": "b8a7b757-8900-4801-a4e9-c108e5716e1a"
      },
      "execution_count": 16,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "27/27 [==============================] - 1s 36ms/step - loss: 0.1192 - accuracy: 0.9749\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print('Test set\\n  Loss: {:0.3f}\\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "RGQsqrjXhuMa",
        "outputId": "9dc5d6f8-8596-41ba-a167-8510ab8b71d5"
      },
      "execution_count": 17,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Test set\n",
            "  Loss: 0.119\n",
            "  Accuracy: 0.975\n"
          ]
        }
      ]
    }
  ]
}
